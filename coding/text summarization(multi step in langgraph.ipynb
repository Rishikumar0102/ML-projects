# %%
# Out:
# Enter a topic for the blog:  Human robot
# 📝 Final Generated Blog Post:
#
# This is a great start! The expanded outline is thorough and covers a lot of ground. Here's a refined version focusing on clarity, readability, and engagement, with suggestions for making it more concise and impactful:
#
# **General Principles Applied:**
#
# *   **Focus on Clarity:** Simplifying language, avoiding jargon where possible, and using strong topic sentences.
# *   **Prioritize Readability:** Breaking up long paragraphs, using bullet points effectively, and ensuring a logical flow.
# *   **Enhance Engagement:** Emphasizing the human element, posing questions directly to the reader, and using vivid language.
# *   **Conciseness:**  Streamlining sentences and paragraphs to avoid repetition and unnecessary detail *within the outline itself*. The blog content itself can be more detailed.
#
# **Refined Blog Outline: Human Robots**
#
# ...

# %%
import google.generativeai as genai
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langgraph.graph import StateGraph

# ✅ Step 1: Configure Gemini API
api_key = "AIzaSyBNX8KAXoSP2x3JejdKEX_Dit48YVJR1xg"  # Replace with your actual key
genai.configure(api_key=api_key)

# ✅ Step 2: Initialize LangChain's Gemini model
gemini = ChatGoogleGenerativeAI(model="gemini-2.0-flash", google_api_key=api_key)

# ✅ Step 3: Define a function to summarize text using Gemini
def summarize_text(text):
    prompt = f"Summarize the following text in 3 lines:\n\n{text}"
    response = gemini.invoke(prompt)
    return response.content.strip()

# ✅ Step 4: Function to perform multi-step summarization
def multi_step_summarizer(article):
    # Step 4.1: Split the article into sections
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=50)
    sections = text_splitter.split_text(article)

    # Step 4.2: Summarize each section
    summaries = [summarize_text(section) for section in sections]

    # Step 4.3: Combine all section summaries into a final summary
    final_summary = summarize_text(" ".join(summaries))

    return final_summary

# ✅ Step 5: Define a Sample Long Article
long_article = """
Artificial Intelligence (AI) is a field of computer science that focuses on creating systems that can perform 
tasks that typically require human intelligence. It includes machine learning, natural language processing, and 
robotics. Machine learning allows computers to learn from data and make decisions without explicit programming. 
Natural language processing (NLP) enables machines to understand human language. Robotics combines AI with 
mechanical engineering to create intelligent robots. AI has applications in healthcare, finance, and many other 
fields. However, it also raises ethical concerns regarding privacy and job displacement.
"""

# ✅ Step 6: Run the Multi-Step Summarizer
final_summary = multi_step_summarizer(long_article)

# ✅ Step 7: Print the Final Summary
print("🔹 Final Multi-Step Summary:")
print(final_summary)
# Out:
# 🔹 Final Multi-Step Summary:
# AI is a multidisciplinary field aiming to create intelligent systems that mimic human cognitive abilities.
# Key areas like machine learning and natural language processing are integrated into robotics and other fields like healthcare and finance.
# AI's advancements present ethical challenges concerning privacy, job displacement, and require expertise in computer science, data analysis, and mechanical engineering.
