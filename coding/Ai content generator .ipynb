# %%
import google.generativeai as genai
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph

# ✅ Set API key for Gemini
api_key = "AIzaSyBNX8KAXoSP2x3JejdKEX_Dit48YVJR1xg"  # Replace with your actual key
genai.configure(api_key=api_key)

# ✅ Initialize Gemini 2.0 Flash
gemini = ChatGoogleGenerativeAI(model="gemini-2.0-flash", google_api_key=api_key)

# ✅ Define State Schema for LangGraph
class BlogState:
    def __init__(self, topic):
        self.topic = topic
        self.outline = None
        self.sections = None
        self.final_content = None

# ✅ Step 1: Generate an Outline
def generate_outline(state):
    prompt = f"Create a structured blog outline for the topic: {state['topic']}."
    response = gemini.invoke(prompt).content
    return {"outline": response}

# ✅ Step 2: Expand Sections in One API Call
def expand_sections(state):
    outline = state["outline"]
    prompt = f"Expand each section from this outline:\n{outline}"
    response = gemini.invoke(prompt).content
    return {"sections": response}

# ✅ Step 3: Refine the Content
def refine_content(state):
    prompt = f"Refine this blog content for clarity and readability:\n{state['sections']}"
    response = gemini.invoke(prompt).content
    return {"final_content": response}

# ✅ Build LangGraph Workflow
workflow = StateGraph(dict)  # Use dict instead of class-based state

workflow.add_node("generate_outline", generate_outline)
workflow.add_node("expand_sections", expand_sections)
workflow.add_node("refine_content", refine_content)

workflow.set_entry_point("generate_outline")
workflow.add_edge("generate_outline", "expand_sections")
workflow.add_edge("expand_sections", "refine_content")

# ✅ Compile the Workflow
graph = workflow.compile()

# ✅ User Input and Execution
user_topic = input("Enter a topic for the blog: ")
state = {"topic": user_topic}
output = graph.invoke(state)

# ✅ Print Final Blog Content
print("\n📝 Final Generated Blog Post:\n")
print(output["final_content"])
# Out:
# Enter a topic for the blog:  human robot
# 📝 Final Generated Blog Post:
#
# Okay, here's a refined version of the blog content, focusing on clarity, readability, and engagement. I've addressed areas where the writing felt repetitive, overly formal, or lacked a clear flow. I've also aimed for a more conversational tone.
#
# **I. Introduction (Captivating Hook & Overview)**
#
# *   **Hook:**
#
#     *   **Option 1 (Statistic - Refined):** "Imagine a world where robots are as common as smartphones. By 2030, experts predict that over 40% of households in developed nations will have some form of robot assistant. From automated vacuum cleaners to more sophisticated companions, are we truly ready for this level of integration? Are our homes, workplaces, and even our *minds* prepared for a future increasingly shaped by machines?"
#     *   **Option 2 (Thought-Provoking Question - Refined):** "Robots: are they the key to a brighter future, or a slippery slope toward a dystopian one? Imagine robots as colleagues, caregivers, and even companions, woven into the fabric of our daily lives. Will this lead to increased efficiency and well-being, or a world of job displacement and social isolation? The answer, just like the field of Human-Robot Interaction, is complex and constantly evolving."
#     *   **Option 3 (Captivating Anecdote - Refined):** "It turns out, people are more likely to trust a robot with a friendly, modulated voice than one with a monotone, mechanical delivery.  This seemingly small detail, highlighted in a recent study from *[Insert reputable journal name]*, reveals a big truth: we're not just interacting with technology; we're building relationships, imbuing robots with human-like qualities, and responding emotionally. What does this say about us, and what does it mean for our future alongside robots?"
#
# *   **Briefly Define "Human-Robot Interaction (HRI)":** "So, what exactly *is* Human-Robot Interaction (HRI)? It's not just about pressing a button on a machine. HRI is a multidisciplinary field exploring the complex relationship between humans and robots. It's a mix of technology, psychology, sociology, and ethics. We're talking about how we *perceive* robots, how we *communicate* with them, how much we *trust* them, and the impact they have on our lives and society."
#
# *   **State the Blog's Purpose/Thesis:** "This blog post is your deep dive into the world of Human-Robot Interaction. We'll explore the current landscape, showcasing real-world applications and the tech that makes it all possible. We'll also look at the *benefits* of humans and robots working together, from increased efficiency to improved quality of life. But we won't shy away from the tough questions: the ethical dilemmas, technical limitations, and potential social and psychological impacts. Finally, we'll gaze into the crystal ball and explore emerging trends, emphasizing the importance of responsible development to ensure HRI benefits *everyone*."
#
# *   **Outline the Key Topics (Roadmap):** "Here's what we'll be covering:
#
#     *   **The Here and Now:** Robots in action across industries, from factories to hospitals.
#     *   **The Tech Behind the Magic:** Computer vision, natural language processing, AI – the core technologies that make HRI tick.
#     *   **Working Together: The Upsides:** How human-robot partnerships boost efficiency, safety, and quality of life.
#     *   **Navigating the Challenges:** Ethical concerns, job displacement, bias in AI, and that creepy "uncanny valley."
#     *   **The Road Ahead:** Future trends and the importance of responsible development for a positive future."
#
# **II. Current State of Human-Robot Interaction**
#
# *   **A. Robots in Different Sectors (Examples & Applications):**
#
#     *   **Industry/Manufacturing (Refined):** "Robots have been mainstays in manufacturing for years, handling repetitive and physically demanding tasks. Think robotic arms welding, painting, and assembling components with incredible speed and precision.  But now, we're seeing the rise of *collaborative robots*, or 'cobots,' designed to work *alongside* human workers.  For example, in car manufacturing, cobots help tighten bolts or lift heavy parts, reducing strain on human workers and boosting production.  And don't forget warehouse management! Companies like Amazon and Ocado use sophisticated robotic systems to sort, pack, and transport goods with amazing speed and accuracy."
#     *   **Healthcare (Refined):** "Healthcare is rapidly embracing robots to improve patient care and empower medical professionals.  Robotic surgery systems, like the da Vinci, allow surgeons to perform complex procedures with greater precision and less invasiveness, leading to faster recovery times. Rehabilitation robots help patients regain mobility after strokes or injuries.  We're even seeing robots in elderly care, providing companionship, monitoring vital signs, and reminding patients to take their medication. Plus, automated dispensing systems use robots to accurately dispense medication, reducing the risk of human error and boosting patient safety."
#     *   **Service Industry (Refined):** "From restaurants to hotels, robots are starting to make their presence known.  Some restaurants are experimenting with robotic chefs that can whip up salads or pizzas. Hotels are using robots to deliver amenities, provide concierge services, and even clean rooms.  Robotic cleaning services are becoming more common in offices and public spaces. Security robots patrol premises, monitoring for anything suspicious.  While all this offers potential efficiency and cost savings, it also sparks questions about jobs and customer experience.  Will you prefer a robotic bartender or a human one?"
#     *   **Education (Refined):** "Robots are finding creative uses in education. They can act as tutors, assist in special education, and teach STEM concepts.  Robotic tutors can provide personalized instruction and feedback, adapting to each student's learning style.  In special education, robots can help children with autism develop communication skills and navigate social interactions.  And of course, robotics kits and programming platforms like Lego Mindstorms and VEX Robotics are widely used to teach students about coding, engineering, and problem-solving."
#     *   **Exploration/Research (Refined):** "Robots are invaluable for exploring environments too dangerous or inaccessible for humans.  Think space exploration: rovers like Curiosity and Perseverance are crucial for studying the Martian surface and searching for signs of life.  Deep-sea research relies on remotely operated vehicles (ROVs) to explore the ocean depths. Robots are also used in hazardous environments like nuclear power plants and disaster zones to assess damage and assist with rescue operations.  These robots are equipped with specialized sensors and tools that allow them to perform tasks that would be impossible or extremely risky for humans."
#
# *   **B. Key Technologies Enabling HRI:**
#
#     *   **Computer Vision (Refined):** "Imagine giving a robot the power to *see*. That's what computer vision does! It uses cameras and algorithms to analyze images and videos, enabling robots to identify objects, recognize faces, track movement, and understand spatial relationships.  This is essential for robots to navigate, avoid obstacles, and interact with humans effectively.  For example, a robot using computer vision can recognize a person's facial expressions and respond accordingly.  Advances in deep learning have made computer vision systems more accurate and reliable in real-world conditions."
#     *   **Natural Language Processing (NLP) (Refined):** "Want to have a conversation with a robot?  That's where Natural Language Processing (NLP) comes in.  NLP allows robots to understand, interpret, and generate human language.  This includes things like speech recognition, text analysis, and machine translation.  With NLP, you can interact with robots using natural language – asking questions, giving instructions, and receiving feedback.  Virtual assistants like Siri and Alexa rely heavily on NLP.  In HRI, NLP can be used to create robots that can engage in meaningful conversations, provide personalized assistance, and learn from human interactions."
#     *   **Artificial Intelligence (AI) & Machine Learning (ML) (Refined):** "AI and Machine Learning (ML) are the brains behind the increasing autonomy and adaptability of robots.  AI allows robots to perform tasks that typically require human intelligence, like problem-solving and decision-making.  ML enables robots to learn from data, improve their performance over time, and adapt to changing environments.  For example, a robot using ML can learn to recognize different objects by analyzing a large dataset of images.  These technologies are crucial for enabling robots to operate independently and interact with humans intuitively."
#     *   **Sensors & Actuators (Refined):** "Sensors and actuators are the physical components that give robots their senses and ability to move.  Sensors allow robots to perceive their environment, detecting things like temperature, pressure, light, sound, and proximity.  Actuators are the motors and mechanisms that allow robots to move, manipulate objects, and perform actions.  For example, a robot might use a touch sensor to detect when it has grasped an object, or a proximity sensor to avoid collisions. Advances in sensor technology are leading to smaller, more accurate, and more energy-efficient sensors."
#     *   **Robotics Hardware (Design & Materials) (Refined):** "The physical form of a robot is determined by its hardware and the materials used to build it.  Traditional robots are often made of rigid materials like metal and plastic, but we're seeing a trend towards *soft robotics*, which uses flexible materials like elastomers and textiles.  The design must consider factors like size, weight, power, and durability. The choice of materials affects the robot's strength, flexibility, and ability to withstand harsh conditions.  For example, robots used in space must be able to withstand extreme temperatures and radiation.  The development of new materials is enabling the creation of robots with increasingly sophisticated designs."
#
# **III. Benefits of Human-Robot Collaboration**
#
# *   **A. Increased Efficiency and Productivity (Refined):** "Teaming up humans and robots can seriously boost efficiency and productivity across industries. Robots are great at repetitive, monotonous, and physically demanding tasks that can be tiring for humans. By automating these tasks, robots free up human workers to focus on more complex, creative, and strategic activities. For example, in manufacturing, cobots can assist with assembly line tasks, increasing production speed and reducing errors. Studies have shown that incorporating cobots can increase production output by as much as 30% while reducing labor costs. It's a win-win."
#
# *   **B. Improved Safety and Reduced Risk (Refined):** "One of the most compelling reasons to embrace HRI is the potential to improve safety. Robots can be deployed in dangerous situations where human exposure to risk is unacceptable. Think handling hazardous materials, working in contaminated areas, or responding to disasters. For instance, robots are used in nuclear power plants to inspect and repair equipment in radioactive environments, minimizing the risk to human workers. In disaster relief, robots can search for survivors in collapsed buildings, reducing the risk to rescue personnel. By taking on these dangerous tasks, robots can protect human lives and prevent injuries."
#
# *   **C. Enhanced Quality of Life (Refined):** "HRI can dramatically improve the quality of life for individuals with disabilities, the elderly, and those in need of assistance. Robots can provide companionship, help with daily tasks, and improve accessibility. For example, robots can help elderly individuals with mobility issues navigate their homes, prepare meals, and manage medications. They can also provide companionship and combat social isolation. For individuals with disabilities, robots can assist with tasks like dressing and bathing, enabling them to live more independently. The potential to transform lives is huge."
#
# *   **D. New Job Creation and Economic Growth (Refined):** "While job displacement is a valid concern, HRI can also *create* new job opportunities and drive economic growth. Developing, deploying, and maintaining robots requires a skilled workforce. This means new jobs in robotics engineering, software development, data science, and ethical oversight. The growth of the robotics industry can also spark innovation and create new business opportunities in related fields. Furthermore, the increased efficiency enabled by HRI can boost economic output and create new wealth. We need to invest in education and training to prepare workers for the jobs of the future."
#
# **IV. Challenges and Concerns of Human-Robot Interaction**
#
# *   **A. Ethical Considerations:**
#
#     *   **Bias in AI (Refined):** "AI algorithms learn from data, and if that data is biased, the AI will be biased too. In HRI, this can lead to robots that discriminate against certain groups of people. For example, a facial recognition system trained primarily on images of white faces may be less accurate at recognizing faces of other ethnicities. This can have serious consequences in applications like security.  We need to address bias in AI by using diverse datasets, developing bias detection techniques, and ensuring that AI systems are fair."
#     *   **Job Displacement (Refined):** "One of the biggest concerns: robots replacing human workers. As robots become more capable, they're increasingly being used to automate tasks previously done by humans. This can lead to job losses in industries like manufacturing and customer service. While HRI can also create new jobs, there's concern that these new jobs may require different skills. Addressing job displacement requires investing in education and training, providing support for displaced workers, and exploring alternative economic models."
#     *   **Privacy and Security (Refined):** "Robots are often equipped with sensors and cameras that collect data about their surroundings, including information about people. This raises concerns about privacy and security. There's a risk that this data could be misused, hacked, or shared without consent. Furthermore, robots themselves can be vulnerable to hacking.  Protecting privacy and security requires strong data protection policies, robust security measures, and ethical guidelines."
#     *   **Autonomous Weapons (Refined):** "The development of autonomous weapons, or 'killer robots,' raises profound ethical questions. These weapons can make life-or-death decisions without human intervention. This raises questions about accountability and the potential for unintended consequences. Critics argue that autonomous weapons should be banned. The ethical risks are significant, and there's a growing international movement to regulate or ban them."
#
# *   **B. Technical Limitations:**
#
#     *   **Reliability and Safety (Refined):** "Ensuring that robots function reliably and safely in complex environments is a major challenge. Robots can malfunction or cause accidents, potentially leading to injuries. Developing robots that are robust, fault-tolerant, and able to handle unexpected situations is crucial. This requires rigorous testing, advanced safety mechanisms, and clear protocols for human intervention."
#     *   **Adaptability and Flexibility (Refined):** "While robots excel at pre-programmed tasks, they often struggle to adapt to unexpected situations. Robots may have difficulty recognizing new objects or navigating unfamiliar environments. Improving adaptability requires advanced AI algorithms, sophisticated sensor systems, and the ability to learn from experience."
#     *   **Cost and Accessibility (Refined):** "The high cost of developing and deploying robots can be a barrier to widespread adoption. Robotics systems can be expensive to design, build, and maintain. Reducing the cost of robotics technology and making it more accessible is crucial. This requires advances in manufacturing techniques and the development of open-source robotics platforms."
#
# *   **C. Social and Psychological Impacts:**
#
#     *   **The "Uncanny Valley" (Refined):** "Ever feel creeped out by a robot that looks *almost* human? That's the 'uncanny valley.' As robots become more realistic, they can trigger a sense of discomfort. This is because the subtle imperfections in their appearance can be unsettling. Avoiding the uncanny valley requires careful attention to detail in robot design."
#     *   **Social Isolation (Refined):** "Could robots replace human interaction and lead to social isolation? It's a concern, particularly for vulnerable populations like the elderly. If robots become the primary source of companionship, people may have fewer opportunities to interact with other humans. We need to design robots that *complement*, rather than replace, human interaction."
#     *   **Trust and Acceptance (Refined):** "Building trust in robots is essential. People may be hesitant to trust robots with important tasks. Building trust requires transparency, accountability, and clear communication about the capabilities and limitations of robots. It's also important to involve the public in discussions about the ethical and social implications of HRI."
#
# **V. The Future of Human-Robot Interaction**
#
# *   **A. Emerging Trends and Technologies:**
#
#     *   **Soft Robotics (Refined):** "Imagine robots made from flexible materials. That's soft robotics! These robots can deform and adapt to their environment, making them ideal for tasks that require delicate manipulation or exploration of confined spaces. They have potential applications in healthcare, manufacturing, and disaster relief."
#     *   **Swarm Robotics (Refined):** "Swarm robotics involves coordinating large groups of robots to accomplish complex tasks. Each robot is relatively simple, but by working together, the swarm can achieve goals that would be impossible for a single robot. Think environmental monitoring, search and rescue, and infrastructure maintenance."
#     *   **Brain-Computer Interfaces (BCIs) (Refined):** "Imagine controlling robots directly with your *mind*. That's the promise of Brain-Computer Interfaces (BCIs)! BCIs use sensors to detect brain activity and translate it into commands that can be used to control a robot. This technology has the potential to revolutionize HRI, allowing people with disabilities to control assistive devices."
#     *   **Virtual and Augmented Reality (VR/AR) in HRI (Refined):** "VR and AR are being used to enhance HRI in a variety of ways. VR can be used to create simulations for training robots. AR can be used to overlay digital information onto the real world, providing humans with enhanced situational awareness. VR/AR technologies have the potential to make HRI more intuitive and efficient."
#
# *   **B. Predicting Future Applications:**
#
#     *   **Personalized Healthcare (Refined):** "In the future, robots are likely to play an increasingly important role in personalized healthcare, providing customized care based on individual needs. Think monitoring vital signs, administering medications, providing physical therapy, and offering companionship."
#     *   **Smart Homes and Cities (Refined):** "Robots are poised to become integral components of smart homes and cities, managing energy consumption, security, and transportation. In smart homes, robots could automate tasks like cleaning and cooking. In smart cities, robots could manage traffic flow and monitor air quality."
#     *   **Sustainable Agriculture (Refined):** "Robots have the potential to transform agriculture, optimizing crop yields, reducing pesticide use, and monitoring environmental conditions. Agricultural robots could plant seeds, harvest crops, weed fields, and monitor soil conditions."
#     *   **Space Colonization (Refined):** "Robots will be essential for preparing for and assisting with human settlements on other planets. They could build habitats, extract resources, and prepare the environment for human habitation."
#
# *   **C. The Importance of Responsible Development (Refined):** "As HRI technology advances, it's crucial to prioritize responsible development, ensuring that it benefits humanity and minimizes risks. This requires ethical guidelines, safety regulations, and public discourse. Governments, researchers, and industry all have a role to play in shaping the future of HRI in a way that is ethical and sustainable."
#
# **VI. Conclusion (Summary & Call to Action)**
#
# *   **Recap Key Takeaways (Refined):** "So, we've journeyed through the fascinating world of Human-Robot Interaction. We've seen how robots are transforming industries and improving lives, and we've explored the technologies that make it all possible. We've also acknowledged the challenges and concerns, and we've looked towards the future, emphasizing the importance of responsible development."
#
# *   **Reiterate Importance of Responsible Development (Refined):** "The future of HRI depends on developing and deploying these technologies responsibly. We must address the ethical concerns, mitigate the risks, and ensure that HRI benefits everyone. This requires collaboration between governments, researchers, industry, and the public."
#
# *   **Offer a Call to Action (Refined):**
#
#     *   **Learn More:** "Dive deeper into HRI! There are tons of resources online – research papers, articles, and videos."
#     *   **Share Your Thoughts:** "What do *you* think about the future of HRI? Are robots a force for good or a potential threat? Share your thoughts in the comments!"
#     *   **Further Reading:** "Check out the websites of the IEEE Robotics and Automation Society and the International Journal of Social Robotics for more in-depth information."
#     *   **Consider Ethical Implications:** "Think about the ethical implications of HRI in your own life. How can we ensure that these technologies are used in a way that is fair and beneficial for all?"
#
# **VII. Optional Additions (No Changes - These are good suggestions)**
#
# *   **Infographics:**
#     *   A visual representation of the different sectors where robots are used.
#     *   A breakdown of the key technologies enabling HRI.
#     *   A comparison of the benefits and challenges of HRI.
#     *   A timeline of the evolution of HRI.
# *   **Videos:**
#     *   A video showcasing robots in action in a manufacturing setting.
#     *   A video demonstrating how robots are used in healthcare.
#     *   A video featuring a panel discussion on the ethical implications of HRI.
# *   **Expert Quotes:**
#     *   "The key to successful HRI is designing robots that are intuitive, trustworthy, and easy to use." - *[Quote from a robotics engineer]*
#     *   "We need to ensure that AI is developed in a way that is fair, transparent, and accountable." - *[Quote from an AI ethicist]*
#     *   "HRI has the potential to transform our lives for the better, but we must proceed with caution and foresight." - *[Quote from a social scientist]*
# *   **Interactive Elements:**
#     *   A poll asking readers about their level of trust in robots.
#     *   A quiz testing readers' knowledge of HRI concepts.
#     *   A survey asking readers about their concerns about the future of HRI.
#
# **Key Improvements Made:**
#
# *   **More Conversational Tone:**  Replaced formal language with a more engaging and accessible style.
# *   **Reduced Repetition:** Eliminated redundant phrases and ideas.
# *   **Stronger Hooks:** Crafted more compelling opening sentences and questions.
# *   **Clearer Explanations:** Simplified complex concepts and provided more relatable examples.
# *   **Emphasis on "Why It Matters":**  Highlighted the real-world impact and significance of HRI.
# *   **Concise and Focused Sentences:**  Broke down long sentences into shorter, more digestible units.
# *   **Stronger Calls to Action:**  Encouraged reader engagement and further exploration.
#
# This refined content should be more engaging, informative, and enjoyable for your target audience. Good luck with your blog post! Remember to choose the hook that best suits your style and audience.
